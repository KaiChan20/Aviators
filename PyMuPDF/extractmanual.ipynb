# %%
from pathlib import Path
import fitz
path = "/Users/poth/Documents/Fall2022/DEAN690/TCDS1/2A13.pdf"
pdf = fitz.open(path)

# %%
page = pdf.loadPage(0)
#_, _, p_width, p_height = page.MediaBox
text = page.getText()

# %%
print(text)
# Out:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# DEPARTMENT OF TRANSPORTATION
# FEDERAL AVIATION ADMINISTRATION
# 2A13
# Revision 63
# Piper Aircraft, Inc
# PA-28-140
# PA-28-151
# PA-28-150
# PA-28-161
# PA-28-160
# PA-28-181
# PA-28-180
# PA-28R-201
# PA-28-235
# PA-28R-201T
# PA-28S-160
# PA-28-236
# PA-28S-180
# PA-28RT-201
# PA-28R-180
# PA-28RT-201T
# PA-28R-200
# ...

# %%
start1 = "Type Certificate Holder "
end1 = "Type Certificate Holder Record"
A1=(text.split(start1))[1].split(end1)[0]
print(A1)
# Out:
# Piper Aircraft, Inc.
# 2926 Piper Drive
# Vero Beach, Florida 32960

# %%
start2 = "Type Certificate Holder Record "
end2 = "I "
A2=(text.split(start2))[1].split(end2)[0]
print(A2)
# Out:
# The New Piper Aircraft, Inc transferred TC 2A13 to Piper Aircraft, Inc on August 7,
# 2006.

# %%
start3 = "Engine"
end3 = "Fuel"
A3=(text.split(start3))[1].split(end3)[0]
print(A3)
# Out:
#
# Lycoming O-320-B2B or O-320-D2A with carburetor setting 10-3678-32

# %%
start4 = "Propeller and Propeller Limits"
end4 = "Propeller Spinner"
A4=(text.split(start4))[1].split(end4)[0]
print(A4)
# Out:
#
# Sensenich M74DM or 74DM6 on S/N 28-1 through 28-1760, and 28-1760A.
# Sensenich M74DMS or 74D6S5 on S/N 28-1761 through 28-4377.
# Static r.p.m. at maximum permission throttle setting not over 2425 r.p.m.,
# not under 2325 r.p.m.
# No additional tolerance permitted.
# Diameter: Not over 74", not under 72.5".

# %%
start5 = "ADMINISTRATION"
end5 = "Revision"
A5=(text.split(start5))[1].split(end5)[0]
print(A5)
# Out:
#
# 2A13

# %%
pc = pdf.pageCount
print(pc)
# Out:
# 47

# %%
with fitz.open(path) as doc:
    for page in doc:
        text2 = page.getText()
        print(text2)
# Out:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# DEPARTMENT OF TRANSPORTATION
# FEDERAL AVIATION ADMINISTRATION
# 2A13
# Revision 63
# Piper Aircraft, Inc
# PA-28-140
# PA-28-151
# PA-28-150
# PA-28-161
# PA-28-160
# PA-28-181
# PA-28-180
# PA-28R-201
# PA-28-235
# PA-28R-201T
# PA-28S-160
# PA-28-236
# PA-28S-180
# PA-28RT-201
# PA-28R-180
# PA-28RT-201T
# PA-28R-200
# ...

# %%
import pandas as pd
data = [['TCDS number',A5],['Type Certificate Holder',A1],['Type Certificate Holder Record',A2],['Engine',A3],['Propeller',A4]]
df = pd.DataFrame(data, columns=['key terms', 'Information'])
df
# Out:
#                         key terms  \
# 0                     TCDS number
# 1         Type Certificate Holder
# 2  Type Certificate Holder Record
# 3                          Engine
# 4                       Propeller
#
#                                          Information
# 0                                          \n2A13 \n
# 1  \nPiper Aircraft, Inc. \n2926 Piper Drive \nVe...
# 2  \nThe New Piper Aircraft, Inc transferred TC 2...
# 3   \nLycoming O-320-B2B or O-320-D2A with carbur...
# 4   \nSensenich M74DM or 74DM6 on S/N 28-1 throug...

# %%
writer=pd.ExcelWriter('try.xlsx',engine='xlsxwriter')
df.to_excel(writer, index=False)
writer.save()
