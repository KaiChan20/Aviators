# %%
import re

# %%
myfile = open("/Users/sarojsiril/Desktop/DAEN 690/tcds/text/A10CE_Rev_67.txt", "rt")
contents = myfile.read()         
myfile.close()                 
print(contents)
# Out:
# DEPARTMENT OF TRANSPORTATION
# FEDERAL AVIATION ADMINISTRATION
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# A10CE
# Revision 67
# LEARJET
#
# 24
# 24A
# 24B
# 24B-A
# 24C
# 24D
# 24D-A
# 24E
# 24F
# 24F-A
# 25
# 25A
# 25B
# 25C
#
# 25D
# 25F
# 28
# 29
# 31
# 31A
# 35
# 36
# 35A (C-21A)
# 36A
# 55
# 55B
# 55C
# 60
#
#
#
# February 19, 2015
#
#
#     |
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     |
#
#
#
# TYPE CERTIFICATE DATA SHEET NO. A10CE
#
#
#
# Learjet Inc.
# One Learjet Way
# Wichita, Kansas  67209-2942
#
# This data sheet which is part of Type Certificate No. A10CE prescribes conditions and limitations under which the product for
# which the type certificate was issued meets the airworthiness requirements of the Federal Aviation Regulations.
#
# Type Certificate Holder
#
#
#
#
# I.  Model 24 (Transport Aircraft), Approved March 17, 1966
#   Model 24A (Transport Aircraft), Approved April 5, 1966
#
#   Engines
#
#
#
#   Fuel
#
#   Engine Limits
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...

# %%
new = re.compile(r'\d{2} [A-Z].*')
for line in contents.split('\n'):
    if new.match(line):
        print(line)
# Out:
# 99 KIAS
# 90 KIAS
# 90 KIAS
# 94 KIAS
# 93 KIAS (8° flap)
# 87 KIAS (20° flap)
# 93 KIAS (8°flap)
# 87 KIAS (20° flap)
