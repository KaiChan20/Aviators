# %%
import string
import pandas as pd
import fitz
import os

# %%
#### add page to all words
def add_page(in_put, value):
    lst = []
    out = []
    index = 0

    for i in range(0, len(in_put)):
        if(i < len(in_put)-1):
            out += [[]]
            lst += in_put[i]
            lst.insert( 8, value+1)
            out[index] = lst
            index += 1
            lst = []
        else:
            out +=[[]]
            lst += in_put[i]
            lst.insert( 8, value+1)
            out[index] = lst

    return out
#--------------------------------------------------------------------------------------------------------
#get all text from given pdf file
def get_all_text(data):
    page_count = data.page_count
    out = []
    for i in range(0, page_count):
        load_page = data.load_page(i)
        #WC stand for word with coordinate
        WC = load_page.get_text('words')
        agw = add_page(WC, i)
        out += agw
    
    return out
# out == [x0, y0, x1, y1, word, block_no, line_no, word_no, page]  
#---------------------------------------------------------------------------------------------------------
# merge the words by block_no and line_no
def word_line(in_put):
    #in_put += [in_put[-1]]
    index = 0
    lst = []
    out = []
    for i in range(0, len(in_put)-1):
        # in_put[i][7] == word_no
        if(in_put[i][7]+1 == in_put[i+1][7]):
            lst += [in_put[i][4]]  
        else:
            if(in_put[i+1][7] == 0):
                lst += [in_put[i][4]]
                lst = [' '.join(lst)]
                lst += [in_put[i][5], in_put[i][6], in_put[i][7],in_put[i][8]]
                lst.insert( 0, in_put[i-in_put[i][7]][0])
                lst.insert( 1, in_put[i-in_put[i][7]][1])
                lst.insert( 2, in_put[i][2])
                lst.insert( 3, in_put[i][3])
            out += [[]]
            out[index] += lst
            index += 1
            lst = []
    return out
#--------------------------------------------------------------------------------------------------------
# 12/07
# Sometimes the y coordinates in the same line will be a little different,
# the smaller y, the higher position
# example: A & B in the same line 
# y0 of A ==1, y0 of B == 0.9 
# the order will be changed to B A since the y is more sensitive condition of the coming reorder work
# This function is to make the texts in the same line have the same y
def Same_y(df):
    fill = [0,9999,0,9999,0,0,0,0,0,0]
    df += [fill]
    num = 0
    big_y = 99999
    highery = big_y
    
    for i in range(0, len(df)-1):        
        # Smaller Y  == higher position in the file 
        # df[i][1] == Y0, df[i][3] == Y1
        # if the average Y of text i in the between of the Ys of text i-1, we say they are the same line 
        if((df[i][1]+df[i][3])/2 > df[i+1][1]) & ((df[i][1]+df[i][3])/2 < df[i+1][3]) & (df[i][1] < highery):
            highery = df[i][1]
            num += 1
            #print(num)
        elif((df[i][1]+df[i][3])/2 > df[i+1][1]) & ((df[i][1]+df[i][3])/2 < df[i+1][3]):
            num += 1
            #print(num)
        # if the average Y of the text i is smaller than the text i+1, we know the i+1 is next line 
        #elif((df[i][1]+df[i][3])/2 < df[i+1][1]) or (i == len(df)-1):
        else:
            if(num == 0):
                pass
            else:
                for j in range(0, num+1):
                    df[i-j][1] = highery
                num = 0
                highery = big_y
    df.pop(-1)
    

    return df    
#--------------------------------------------------------------------------------------------------------
# Get the X1 of Fuel
def get_fuel_x1(df):
    for i in range(0,len(df)):
        if(df[i][4].lower() == 'fuel') or (df[i][4].lower() == 'fuel:') or (df[i][4].lower() == '*fuel') or (df[i][4].lower() == 'fuel.'):
            return df[i][2]
#--------------------------------------------------------------------------------------------------------
# detect the word lines' class (key_term, header, info)
def detect_khi(df):
    index = 0
    lst = []
    out = []
    for i in range(0,len(df)):
        ## old one add & (in_put[i][6] == 0) in both if & elif
        if(df[i][0] <= fuel_x1) & (df[i][7] < 5 ):
            lst += df[i]
            lst.insert(8, 'key_term')
            out += [[]]
            out[index] = lst
            lst = []
            index += 1
        elif(df[i][0] <= fuel_x1) & (df[i][4].lower().find('model') > 0):
            lst += df[i]
            lst.insert(8, 'header')
            out += [[]]
            out[index] = lst
            lst = []
            index += 1
        else:
            lst += df[i]
            lst.insert(8, 'info')
            out += [[]]
            out[index] = lst
            lst = []
            index += 1

    #print(out_put)
    return out

#---------------------------------------------------------------------------------------------------------------
#12/07
#Drop no need columns (block_no, line_no, word_no)
def Drop_blw(df):
    # df == [x0, y0, x1, y1, word, block_no, line_no, word_no, category, page]    
    lst = []
    index = 0
    out = []
    for i in range(0, len(df)):
        lst += [df[i][0],df[i][1],df[i][2],df[i][3],df[i][4],df[i][8],df[i][9]]
        out += [[]]
        out[index] = lst
        index += 1
        lst = []
    # out == [x0, y0, x1, y1, word, category, page] 
    return out

#----------------------------------------------------------------------------------------------------------------
# Sometimes the header's number will be detect as key term, this function is used to solve it.
# example: real header == I. Model xyz....  and the df might be ['I.', 'key_term'], ['Model xyz...', 'header']
# hder function is to catch 'I.' form keyterm to header.       
def hder(df):
    for i in range(0, len(df)-1):
        if(df[i+1][5] == "header") & (int(df[i][1]) == int(df[i+1][1])):
            df[i][5] = "header"
    return df
#----------------------------------------------------------------------------------------------------------------

# find first line from page2
def firsty1(df):
    lst = []
    page = 1

    for i in range(0, len(df)-1):
        if(df[i][6] == page+1):
            lst += [df[i][3]]
            page += 1
    #print(lst)
    return lst

#--------------------------------------------------------------------------------------------------------
def drop_fline(df, fy):
    lst = []
    y1max = max(fy)
    for i in range(0, len(df)):
        #df[i][6] == page_no
        if(df[i][6] > 1) & (df[i][1] < y1max):
            lst += [i]
            print(df[i][4])
#    print(lst)
    lst.reverse()
#    print(lst)
    for j in range(0, len(lst)):
        df.pop(lst[j])
    
    return df
#----------------------------------------------------------------------------------------------------------------
# clean the cont'd stuff in the df
def clean_cont(df):

    lst = []
    num = 0
    page = 1 
    c1 = 'contd'
    c2 = '(cont’d)'
    c3 = '(continued)' 
    c4 = 'cont d'
    c5 = 'cont'
    for i in range(0, len(df)):
        if(df[i][6] == page) & (num < 5):
            num += 1
            if(df[i][4].lower().find(c1) > 0) or (df[i][4].lower().find(c2) > 0) or (df[i][4].lower().find(c3) > 0) or (df[i][4].lower().find(c4) > 0) or (df[i][4].lower().find(c5) > 0):
                lst += [i]
        else:
            num = 0
            page += 1
    #print(lst)
    lst.reverse()
    for j in range(0, len(lst)):
        df.pop(lst[j])
    
    return df

#----------------------------------------------------------------------------------------------------------------
# 11/15
# This function is used to make sure the left side have are all header or keyterm
def all_header(df):
    for i in range(1 , len(df)):
        if(df[i-1][5] == 'header'):
            if(df[i][4].lower() == 'engine') or (df[i][4].lower() == 'engines'):
                pass
            else:
                df[i][5] = 'header'
    return df
#----------------------------------------------------------------------------------------------------------------
#11/25
#Let 'all model' from key term to header
def allmodel_is_header(df):
    
    for i in range(0, len(df)):
        if(df[i][5] == 'key_term') & (df[i][4].lower().find('all') > 0):
            if(df[i][4].lower().find('model') > 0) or (df[i][4].lower().find('models') >= 0 ):
                df[i][5] == 'header'
    
    return df
#----------------------------------------------------------------------------------------------------------------
# 11/19 define the model & revision info of top right in the first page as rev
def df_rev(df):
    fkt = -1
    for i in range(0, len(df)):
        if(df[i][5] == 'key_term') & (fkt < 0):
            fkt = i
#    print(fkt)        
    for i in range(0, fkt):
        if(df[i][0] > 300):
            df[i][5] = 'rev'
    
    return df
#----------------------------------------------------------------------------------------------------------------
def merge_all(df):
    lst = []
    out = []
    index = 0
    num = 0
    for i in range(0, len(df)-1):
        if(df[i][5] == 'header'):
            if(df[i+1][5] == 'header'):
                lst += [df[i][4]]
                num += 1
            else:
                out += [[]]
                lst += [df[i][4]]
                lst = [' \n '.join(lst)]
                lst += [df[i][5]]
                lst.insert( 0, df[i-num][6])
                lst.insert( 1, df[i][1])
                lst.insert( 2, df[i][6])
                lst.insert( 3, df[i][3])
                # out put will be [start page, y start, end page, y end, text, class]
                out[index] = lst
                num = 0
                index += 1
                lst = []

        elif(df[i][5] == 'key_term'):
            out += [[]]
            lst += [df[i][6], df[i][1], df[i][6], df[i][3], df[i][4], df[i][5]]
            out[index] = lst
            index += 1
            lst = []
        
        elif(df[i][5] == 'info'):
            if(df[i+1][5] == 'info'):
                lst += [df[i][4]]
                num += 1
            else:
                out += [[]]
                lst += [df[i][4]]
                lst = [' \n '.join(lst)]
                lst += [df[i][5]]
                lst.insert( 0, df[i-num][6])
                lst.insert( 1, df[i][1])
                lst.insert( 2, df[i][6])
                lst.insert( 3, df[i][3])
                # out put will be [start page, y start, end page, y end, text, class]
                out[index] = lst
                num = 0
                index += 1
                lst = []
                
        elif(df[i][5] == 'rev'):
            if(df[i+1][5] == 'rev'):
                lst += [df[i][4]]
                num += 1
            else:
                out += [[]]
                lst += [df[i][4]]
                lst = [' \n '.join(lst)]
                lst += [df[i][5]]
                lst.insert( 0, df[i-num][6])
                lst.insert( 1, df[i][1])
                lst.insert( 2, df[i][6])
                lst.insert( 3, df[i][3])
                # out put will be [start page, y start, end page, y end, text, class]
                out[index] = lst
                num = 0
                index += 1
                lst = []
    return out

#----------------------------------------------------------------------------------------------------------------
def prep_final_output(df):
    index = 0
    lst = []
    out = []
    
    for i in range(0, len(df)-1):
        if(df[i][5] == 'rev') or (df[i][5] == 'header'):
            out += [[]]
            lst += [df[i][4], '']
            out[index] = lst
            
            lst = []
            index += 1
        
        elif(df[i][5] == 'key_term') & (df[i+1][5] == 'info'):
            lst += [df[i][4]]
        elif(df[i][5] == 'info') & (len(lst) > 0):
            out += [[]]
            lst += [df[i][4]]
            out[index] = lst
            
            lst =[]
            index += 1

    return out

# %%
path = "/Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds"
list_files = os.walk(path)
dfinal = pd.DataFrame() 
a = []
nof = []

for root, dirs, files in os.walk(path):
    for file in files:
        if not file.startswith("."):
            p = os.path.join(root,file)
            print(p)
            pdf = fitz.open(p)
            if pdf == None:
                pass
            else:
                all_text = get_all_text(pdf)
                
                merged_words = word_line(all_text)
                #-----------------------------------
                # Sometimes the y coordinates in the same line will be a little different,
                # the smaller y, the higher position
                # example: A & B in the same line 
                # y0 of A ==1, y0 of B == 0.9 
                # the order will be changed to B A since the y is more sensitive condition of the coming reorder work
                # This function is to make the texts in the same line have the same y
                Sy = Same_y(merged_words)
                
                #-------------------------------------
                #sorted key + lambda 
                # ref: https://blog.csdn.net/w417950004/article/details/86253721
                # reorder the word lines by coordinates (page > y0 > x0)
                St = sorted(Sy, key = lambda x:(int(x[8]), float(x[1]), float(x[0])))
                
                fuel_x1 = get_fuel_x1(St)
                if fuel_x1 == None:
                    nof.append(file)
                    pdf.close()
                else:
                    khi = detect_khi(St)
                    #for i in range(0, len(khi)):
                    #    if(khi[i][8] == 'header'):
                    #        print(khi[i][4])
                    #Cleaned khi
                    Ckhi = Drop_blw(khi)
                    #-----------------------------------------------------------------------------
                    # Sometimes the header's number will be detect as key term, this function is used to solve it.
                    #example: real header == I. Model xyz....  and the df might be ['I.', 'key_term'], ['Model xyz...', 'header']
                    # hder function is to catch 'I.' form keyterm to header.       
                    hder(Ckhi)
                    
                    #-----------------------
                    #clean the page stuff
                    #fy1 function will retun the y1 of the first lines
                    fy1 = firsty1(Ckhi)
                    #use the max value to clean the tc titles which has been detect as KT
                    drop_fline(Ckhi, fy1)
                    #-----------------------------------------------------------------------------
                    C_cont = clean_cont(Ckhi)
                    
                    #---------------------------------------------------------------------------------------------------
                    #drop punctuations of KT
                    #https://datagy.io/python-remove-punctuation-from-string/
                    for i in range(0, len(C_cont)-1):
                        if(C_cont[i][5] == 'key_term'):
                            C_cont[i][4] = C_cont[i][4].translate(str.maketrans('', '', string.punctuation))
                    #-------------------------------------------------------------------------------------------------
                    ah = all_header(C_cont)
                    #---------------------------------------------
                    abc = allmodel_is_header(ah)
                    #----------------------------------------------
                    cde = df_rev(abc)
                    
                    mall = merge_all(cde)
                    #for i in range(0, len(mall)):
                    #    print(mall[i])
                    fout = prep_final_output(mall)
                    
                    b = pd.DataFrame(fout)
                    b.to_csv(rf'/Users/bbteela/Desktop/Work/DAEN 690/csv/{file}.csv', index=False)
                    a.append(b)
        
                    #dfinal.loc[len(dfinal)] = fout
                    pdf.close()
                    #for i in range(0, len(fout)):
                    #    print(fout[i])
                    
                    #dfinal = pd.DataFrame(fout, columns=['L', 'R'])
                    #dfinal

dfinal = pd.concat(a)
no_fuel = pd.DataFrame(nof)
# Out:
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/4A24.pdf
# Page 2 of 9
# 4A24
# Page 3 of 9
# 4A24
# Page 4 of 9
# 4A24
# Page 5 of 9
# 4A24
# Page 6 of 9
# 4A24
# Page 7 of 9
# 4A24
# Page 8 of 9
# 4A24
# Page 9 of 9
# 4A24
# NOTE 1.
# (a) Current weight and balance report including list of equipment included in certificated empty weight,
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/4A30.pdf
# 4A30
# 2
# 3
# 4A30
# 4A30
# 4
# 5
# 4A30
# 4A30
# 6
# 7
# 4A30
# 4A30
# 8
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/3A11.pdf
# 3A11
# 2
# Rev. 7
# Rev. 7
# 3
# 3A11
# 3A11
# 4
# Rev. 7
# Rev. 7
# 5
# 3A11
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/H80EU.pdf
# Gas Temperature
# 948 ºC (1738 ºF)
# One Engine Inoperative (Emergency)
# Center of Gravity (CG) Range.
# Longitudinal limits
# 15 000
# Fuel Capacity.
# Total:
# 1118.88 U.S. Gal. (4235.42 Liters) in 4 tanks of 279.72
# U.S. Gal. (1058.86 Liters) each at Sta. 211.6; 250.98;
# 290.35; 329.72 in (5374.64; 6374.892; 7374.89; 8374.888
# mm) respectively
# issuance of a standard certificate of airworthiness. For further
# information, contact AEU-100 FAA/EMB, PSC 82 Box 002, APO
# AE 09724 or FTW-AEG, DOT/FAA, Fort Worth, TX 76193-0270
# Certification Basis.
# which must be supplied with each rotorcraft at time of delivery.
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/3A10.pdf
# 3A10
# 2
# Rev. 63
# Rev. 63
# 3
# 3A10
# 3A10
# 4
# Rev. 63
# Rev. 63
# 5
# 3A10
# 3A10
# 6
# Rev. 63
# Rev. 63
# 7
# 3A10
# 3A10
# 8
# Rev. 63
# Rev. 63
# 9
# 3A10
# 3A10
# 10
# Rev. 63
# Rev. 63
# 11
# 3A10
# 3A10
# 12
# Rev. 63
# Rev. 63
# 13
# 3A10
# 3A10
# 14
# Rev. 63
# Rev. 63
# 15
# 3A10
# 3A10
# 16
# Rev. 63
# Rev. 63
# 17
# 3A10
# 3A10
# 18
# Rev. 63
# Rev. 63
# 19
# 3A10
# 3A10
# 20
# Rev. 63
# Rev. 63
# 21
# 3A10
# 3A10
# 22
# Rev. 63
# Rev. 63
# 23
# 3A10
# 3A10
# 24
# Rev. 63
# Rev. 63
# 25
# 3A10
# 3A10
# 26
# Rev. 63
# Rev. 63
# 27
# 3A10
# 3A10
# 28
# Rev. 63
# Rev. 63
# 29
# 3A10
# 3A10
# 30
# Rev. 63
# Rev. 63
# 31
# 3A10
# 3A10
# 32
# Rev. 63
# Rev. 63
# 33
# 3A10
# 3A10
# 34
# Rev. 63
# Rev. 63
# 35
# 3A10
# 3A10
# 36
# Rev. 63
# Rev. 63
# 37
# 3A10
# 3A10
# 38
# Rev. 63
# Rev. 63
# 39
# 3A10
# 3A10
# 40
# Rev. 63
# Rev. 63
# 41
# 3A10
# 3A10
# 42
# Rev. 63
# Rev. 63
# 43
# 3A10
# 3A10
# 44
# Rev. 63
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/A-448.pdf
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/A21EA.pdf
# Page 2 of 20
# A21EA
# Page 3 of 20
# A21EA
# Page 4 of 20
# A21EA
# Page 5 of 20
# A21EA
# Page 6 of 20
# A21EA
# Page 7 of 20
# A21EA
# Page 8 of 20
# A21EA
# Page 9 of 20
# A21EA
# Page 10 of 20
# A21EA
# Page 11 of 20
# A21EA
# Page 12 of 20
# A21EA
# Page 13 of 20
# A21EA
# Page 14 of 20
# A21EA
# Page 15 of 20
# A21EA
# Page 16 of 20
# A21EA
# Page 17 of 20
# A21EA
# Page 18 of 20
# A21EA
# Page 19 of 20
# A21EA
# Page 20 of 20
# A21EA
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/5A6.pdf
# 5A6
# 2
# Rev. 68
# Rev. 68
# 3
# 5A6
# 5A6
# 4
# Rev. 68
# Rev. 68
# 5
# 5A6
# 5A6
# 6
# Rev. 68
# Rev. 68
# 7
# 5A6
# 5A6
# 8
# Rev. 68
# Rev. 68
# 9
# 5A6
# 5A6
# 10
# Rev. 68
# Rev. 68
# 11
# 5A6
# 5A6
# 12
# Rev. 68
# Rev. 68
# 13
# 5A6
# 5A6
# 14
# Rev. 68
# Rev. 68
# 15
# 5A6
# 5A6
# 16
# Rev. 68
# Rev. 68
# 17
# 5A6
# 5A6
# 18
# Rev. 68
# Rev. 68
# 19
# 5A6
# 5A6
# 20
# Rev. 68
# Rev. 68
# 21
# 5A6
# 5A6
# 22
# Rev. 68
# Rev. 68
# 23
# 5A6
# 5A6
# 24
# Rev. 68
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/4A19.pdf
# 4A19
# 2 of 4
# 4A19
# 3 of 4
# 4A19
# 4 of 4
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/A-306.pdf
# A-306
# 2
# Rev. 12
# Rev. 12
# 3
# A-306
# A-306
# 4
# Rev. 12
# Rev. 12
# 5
# A-306
# A-306
# 6
# Rev. 12
# Rev. 12
# 7
# A-306
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/4
# Rev. 65
# 13
# 5A4
# 5A4
# 14
# Rev. 65
# Rev. 65
# 15
# 5A4
# 5A4
# 16
# Rev. 65
# Rev. 65
# 17
# 5A4
# 5A4
# 18
# Rev. 65
# Rev. 65
# 19
# 5A4
# 5A4
# 20
# Rev. 65
# Rev. 65
# 21
# 5A4
# 5A4
# 22
# Rev. 65
# Rev. 65
# 23
# 5A4
# 5A4
# 24
# Rev. 65
# Rev. 65
# 25
# 5A4
# 5A4
# 26
# Rev. 65
# Rev. 65
# 27
# 5A4
# 5A4
# 28
# Rev. 65
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/A26CE.pdf
# Rev. 11
# 2
# A26CE
# Rev. 11
# 3
# A26CE
# Rev. 11
# 4
# A26CE
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/A28NM.pdf
# A28NM
# Page 2 of 94
# All models
# A28NM
# Page 3 of 94
# All models
# A28NM
# Page 4 of 94
# All models
# A28NM
# Page 5 of 94
# All models
# A28NM
# Page 6 of 94
# All models
# A28NM
# Page 7 of 94
# All models
# A28NM
# Page 8 of 94
# All models
# A28NM
# Page 9 of 94
# All models
# A28NM
# Page 10 of 94
# All models
# A28NM
# Page 11 of 94
# All models
# A28NM
# Page 12 of 94
# All models
# A28NM
# Page 13 of 94
# All models
# A28NM
# Page 14 of 94
# All models
# A28NM
# Page 15 of 94
# All models
# A28NM
# Page 16 of 94
# All models
# A28NM
# Page 17 of 94
# All models
# A28NM
# Page 18 of 94
# All models
# A28NM
# Page 19 of 94
# All models
# A28NM
# Page 20 of 94
# All models
# A28NM
# Page 21 of 94
# All models
# A28NM
# Page 22 of 94
# All models
# A28NM
# Page 23 of 94
# All models
# A28NM
# Page 24 of 94
# All models
# A28NM
# Page 25 of 94
# All models
# A28NM
# Page 26 of 94
# All models
# A28NM
# Page 27 of 94
# All models
# A28NM
# Page 28 of 94
# All models
# A28NM
# Page 29 of 94
# All models
# A28NM
# Page 30 of 94
# All models
# A28NM
# Page 31 of 94
# All models
# A28NM
# Page 32 of 94
# All models
# A28NM
# Page 33 of 94
# All models
# A28NM
# Page 34 of 94
# All models
# A28NM
# Page 35 of 94
# All models
# A28NM
# Page 36 of 94
# All models
# A28NM
# Page 37 of 94
# All models
# A28NM
# Page 38 of 94
# All models
# A28NM
# Page 39 of 94
# All models
# A28NM
# Page 40 of 94
# All models
# A28NM
# Page 41 of 94
# All models
# A28NM
# Page 42 of 94
# All models
# A28NM
# Page 43 of 94
# All models
# A28NM
# Page 44 of 94
# All models
# A28NM
# Page 45 of 94
# All models
# A28NM
# Page 46 of 94
# All models
# A28NM
# Page 47 of 94
# All models
# A28NM
# Page 48 of 94
# All models
# A28NM
# Page 49 of 94
# All models
# A28NM
# Page 50 of 94
# All models
# A28NM
# Page 51 of 94
# All models
# A28NM
# Page 52 of 94
# All models
# A28NM
# Page 53 of 94
# All models
# A28NM
# Page 54 of 94
# All models
# A28NM
# Page 55 of 94
# All models
# A28NM
# Page 56 of 94
# All models
# A28NM
# Page 57 of 94
# All models
# A28NM
# Page 58 of 94
# All models
# A28NM
# Page 59 of 94
# All models
# A28NM
# Page 60 of 94
# All models
# A28NM
# Page 61 of 94
# All models
# A28NM
# Page 62 of 94
# All models
# A28NM
# Page 63 of 94
# All models
# A28NM
# Page 64 of 94
# All models
# A28NM
# Page 65 of 94
# All models
# A28NM
# Page 66 of 94
# All models
# A28NM
# Page 67 of 94
# All models
# A28NM
# Page 68 of 94
# All models
# A28NM
# Page 69 of 94
# All models
# A28NM
# Page 70 of 94
# All models
# A28NM
# Page 71 of 94
# All models
# A28NM
# Page 72 of 94
# All models
# A28NM
# Page 73 of 94
# All models
# A28NM
# Page 74 of 94
# All models
# A28NM
# Page 75 of 94
# All models
# A28NM
# Page 76 of 94
# All models
# A28NM
# Page 77 of 94
# All models
# A28NM
# Page 78 of 94
# All models
# A28NM
# Page 79 of 94
# All models
# A28NM
# Page 80 of 94
# All models
# A28NM
# Page 81 of 94
# All models
# A28NM
# Page 82 of 94
# All models
# A28NM
# Page 83 of 94
# All models
# A28NM
# Page 84 of 94
# All models
# A28NM
# Page 85 of 94
# All models
# A28NM
# Page 86 of 94
# All models
# A28NM
# Page 87 of 94
# All models
# A28NM
# Page 88 of 94
# All models
# A28NM
# Page 89 of 94
# All models
# A28NM
# Page 90 of 94
# All models
# A28NM
# Page 91 of 94
# All models
# A28NM
# Page 92 of 94
# All models
# A28NM
# Page 93 of 94
# All models
# A28NM
# Page 94 of 94
# All models
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/3A12.pdf
# 3A12
# 2
# Rev. 86
# Rev. 86
# 3
# 3A12
# 3A12
# 4
# Rev. 86
# Rev. 86
# 5
# 3A12
# 3A12
# 6
# Rev. 86
# Rev. 86
# 7
# 3A12
# 3A12
# 8
# Rev. 86
# Rev. 86
# 9
# 3A12
# 3A12
# 10
# Rev. 86
# Rev. 86
# 11
# 3A12
# 3A12
# 12
# Rev. 86
# Rev. 86
# 13
# 3A12
# 3A12
# 14
# Rev. 86
# Rev. 86
# 15
# 3A12
# 3A12
# 16
# Rev. 86
# Rev. 86
# 17
# 3A12
# 3A12
# 18
# Rev. 86
# Rev. 86
# 19
# 3A12
# 3A12
# 20
# Rev. 86
# Rev. 86
# 21
# 3A12
# 3A12
# 22
# Rev. 86
# Rev. 86
# 23
# 3A12
# 3A12
# 24
# Rev. 86
# Rev. 86
# 25
# 3A12
# 3A12
# 26
# Rev. 86
# Rev. 86
# 27
# 3A12
# 3A12
# 28
# Rev. 86
# Rev. 86
# 29
# 3A12
# 3A12
# 30
# Rev. 86
# Rev. 86
# 31
# 3A12
# 3A12
# 32
# Rev. 86
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/A2GL.pdf
# A2GL
# 2
# 3
# A2GL
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/A-2-571.pdf
# A-2-571
# Page 2
# A-2-571
# Page 3
# A-2-571
# Page 4
# A-2-571
# Page 5
# A-2-571
# Page 6
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/R00007RD.pdf
# R00007RD
# 2
# Rev.1
# R00007RD
# 3
# Rev.1
# R00007RD
# 4
# Rev.1
# R00007RD
# 5
# Rev.1
# R00007RD
# 6
# Rev.1
# R00007RD
# 7
# Rev.1
# R00007RD
# 8
# Rev.1
# R00007RD
# 9
# Rev.1
# R00007RD
# 10
# Rev.1
# R00007RD
# 11
# Rev.1
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/7A6.pdf
# Air brake operation
# 306 or Mach 0.81
# Air brake extended
# 306 or Mach 0.81
# 3
# 7A6
# Airspeed limits (CAS)
# Knots
# Fuel
# American:
# JP-1 (MIL-F-5616)
# JP-4 (MIL-F-5624C)
# 5
# 7A6
# A U.S. Airworthiness Certificate may be issued on the basis of Certificate of
# Airworthiness for Export signed by a representative of the Secretariat General a
# 7
# 7A6
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/H10SW.pdf
# 2 of 4
# H10SW
# H10SW
# 3 of 4
# 4 of 4
# H10SW
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/HR-35.pdf
# HR-35
# Page 2 of 2
# Revision 2
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/A-700.pdf
# A-700
# Page 2
# A-700
# Page 3
# A-700
# Page 4
# A-700
# Page 5
# A-700
# Page 6
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/A4PC.pdf
# A4PC
# Page 2
# 3
# A4PC
# A4PC
# Page 4
# 5
# A4PC
# A4PC
# Page 6
# 7
# A4PC
# A4PC
# Page 8
# 9
# A4PC
# A4PC
# Page 10
# 11
# A4PC
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/R0011DE.pdf
# R0011DE
# Page 2 of 7
# R0011DE
# Page 3 of 7
# R0011DE
# Page 4 of 7
# R0011DE
# Page 5 of 7
# R0011DE
# Page 6 of 7
# R0011DE
# Page 7 of 7
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/A-728.pdf
# A-728
# Page 2 of 7
# A-728
# Page 3 of 7
# A-728
# Page 4 of 7
# A-728
# Page 5 of 7
# A-728
# Page 6 of 7
# A-728
# Page 7 of 7
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/H1NM.pdf
# H1NM
# 2
# 3
# H1NM
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/A38EU.pdf
# A38EU
# 2
# 3
# A38EU
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/A00002AC.pdf
# A00002AC
# 2 of 11
# Rev 22
# A00002AC
# 3 of 11
# Rev 22
# A00002AC
# 4 of 11
# Rev 22
# A00002AC
# 5 of 11
# Rev 22
# A00002AC
# 6 of 11
# Rev 22
# A00002AC
# 7 of 11
# Rev 22
# A00002AC
# 8 of 11
# Rev 22
# A00002AC
# 9 of 11
# Rev 22
# A00002AC
# 10 of 11
# Rev 22
# A00002AC
# 11 of 11
# Rev 22
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/3A2.pdf
# 3A2
# 2
# 3
# 3A2
# 3A2
# 4
# 5
# 3A2
# 3A2
# 6
# 7
# 3A2
# 3A2
# 8
# 9
# 3A2
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/1A17.pdf
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/R00020LA.pdf
# R00020LA
# Page 2 of 5
# R00020LA
# Page 3 of 5
# R00020LA
# Page 4 of 5
# R00020LA
# Page 5 of 5
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/A4EU.pdf
# A4EU
# 2
# Rev. 15
# Rev. 15
# 3
# A4EU
# A4EU
# 4
# Rev. 15
# Rev. 15
# 5
# A4EU
# A4EU
# 6
# Rev. 15
# Rev. 15
# 7
# A4EU
# A4EU
# 8
# Rev. 15
# Rev. 15
# 9
# A4EU
# A4EU
# 10
# Rev. 15
# Rev. 15
# 11
# A4EU
# A4EU
# 12
# Rev. 15
# Rev. 15
# 13
# A4EU
# A4EU
# 14
# Rev. 15
# Rev. 15
# 15
# A4EU
# A4EU
# 16
# Rev. 15
# Rev. 15
# 17
# A4EU
# A4EU
# 18
# Rev. 15
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/A15NM.pdf
# A15NM
# 2
# 3
# A15NM
# A15NM
# 4
# 5
# A15NM
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/A50NM.pdf
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/A12IN.pdf
# A12IN
# 2
# 3
# A12IN
# A12IN
# 4
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/A
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/A12SW.pdf
# Airspeed limits
# Never exceed:
# 243 KCAS (280 MPH), S. L. to 18,000 Ft.
# M = 0.51, Above 18,000 Ft.
# 3
# A12SW
# Weight limits
# Maximum
# Equipment
# The basic required equipment as prescribed in the applicable airworthiness
# regulation must be installed in the aircraft for certification. Rockwell Report
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/A00009DE.pdf
# A00009DE
# Page 2 of 5
# Page 3 of 5
# A00009DE
# Rudder
# LEFT
# 25° ± 1°
# RIGHT
# 25° ± 1°
# A00009DE
# Page 4 of 5
# Page 5 of 5
# A00009DE
# Number 0004, 0006, 0007, 0008, 0009, 0010 after incorporation of AMI-
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/A31NM.pdf
# Page 2 of 4
# A31NM
# Page 3 of 4
# A31NM
# Page 4 of 4
# A31NM
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/A6EA.pdf
# A6EA
# 2
# A6EA
# 3
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/R00001RC.pdf
# Airspeed Limitations placard in the Rotorcraft Flight Manual.
# Autorotation VNE 80 KIAS
# Page 2 of 6
# R00001RC
# 1)
# For approved MGW configuration of 2722 kg (6,000 lbs.)
# Page 3 of 6
# R00001RC
# Right 4.6 cm (1.8 in.) at 1724 kg (3800 lb.) changing linearly to 7.1 cm (2.8 in.) at 1814
# Page 4 of 6
# R00001RC
# Page 5 of 6
# R00001RC
# Certification Basis
# 1.
# For approved MGW configuration of 2722 kg (6000 lb.)
# Page 6 of 6
# R00001RC
# NOTE 5
# The model 427 rotorcraft employs electronic engine controls that are recognized to be more
# susceptible to Electromagnetic Interference (EMI) than manual (non-electronic) controls used on
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/1A1.pdf
# 1A1
# 2 of 5
# 3 of 5
# 1A1
# 1A1
# 4 of 5
# 5 of 5
# 1A1
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/A-729.pdf
# A-729
# 2
# 3
# A-729
# A-729
# 4
# 5
# A-729
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/R00019AT.pdf
# Page 2 of 8
# R00019AT
# Page 3 of 8
# R00019AT
# Page 4 of 8
# R00019AT
# Page 5 of 8
# R00019AT
# Page 6 of 8
# R00019AT
# Page 7 of 8
# R00019AT
# Page 8 of 8
# R00019AT
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/A-701.pdf
# A-701
# Page 2
# A-701
# Page 3
# A-701
# Page 4
# A-701
# Page 5
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/H8EU.pdf
# 2
# H8EU
# Fuel (cont’d)
# Authorized without restrictions
# 3
# H8EU
# Engine Limits
# Governed speed:
# 43,000 + 1500 rpm
# Maximum speed, takeoff and maximum continuous:
# 44,500 rpm
# 4
# H8EU
# Oil Capacity
# Engine maximum 2.3 U.S. gallons at 206.3 in.
# MGB maximum 2.2 U.S. gallons at 160.6 in.
# Equipment
# The basic required equipment as prescribed in the applicable airworthiness regulations (See Certification
# Basis) must be installed in the helicopter for certification. Aerospatiale Report No. 360A.04.3157 lists
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/A-715.pdf
# A-715
# 2
# 3
# A-715
# A-715
# 4
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/R00024BO.pdf
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/A-649.pdf
# A-649
# 2
# Rev. 5
# Rev. 5
# 3
# A-649
# A-649
# 4
# Rev. 5
# Rev. 5
# 5
# A-649
# A-649
# 6
# Rev. 5
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/7A7.pdf
# Vfe (Flaps extended)
# 115 m.p.h.
# (100 knots)
# Vlle (Landing light extended)
# 150 m.p.h.
# (130 knots)
# Vllo (Landing light operation)
# 150 m.p.h.
# (130 knots)
# 3
# 7A2
# C.G. range
# (+12.5) to (+19.0) at 11,600 lb.
# (+15.0) to (+19.0) at 14,000 lb.
# Straight line variation between points.
# Airspeed limits (I.A.S.)
# Vne (Never exceed)
# 187 m.p.h. (162 knots)
# Vno (Normal operating)
# 168 m.p.h. (146 knots)
# Va (Maneuvering)
# 132 m.p.h. (115 knots)
# 5
# 7A2
# Other operating
# Aircraft shall be operated in compliance with the operating limitations
# limitations
# specified in the appropriate A.R.B. Approved Airplane Flight Manual
# NOTE 1.
# (a) Current weight and balance report, including list of equipment included in certificated empty weight,
# and loading instructions when necessary, must be in each aircraft at the time of original certification and
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/A47CE.pdf
# Page 2 of 14
# A47CE
# Page 3 of 14
# A47CE
# Page 4 of 14
# A47CE
# Page 5 of 14
# A47CE
# Page 6 of 14
# A47CE
# Page 7 of 14
# A47CE
# Page 8 of 14
# A47CE
# Page 9 of 14
# A47CE
# Page 10 of 14
# A47CE
# Page 11 of 14
# A47CE
# Page 12 of 14
# A47CE
# Page 13 of 14
# A47CE
# Page 14 of 14
# A47CE
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/A49NM.pdf
# A49NM 2
# 3 A49NM
# A49NM 4
# 5 A49NM
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/A-675.pdf
# A-675
# Page 2
# Page 3
# A-675
# A-675
# Page 4
# Page 5
# A-675
# KCA, 50-C, S-50-C
# 65-CA
# A-675
# Page 6
# KCA, 50-C, S-50-C
# 65-CA
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/H17NM.pdf
# H17NM
# 2
# 3
# H17NM
# H17NM
# 4
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/5A5.pdf
# 5A5
# 2
# 3
# 5A5
# 5A5
# 4
# 5
# 5A5
# 5A5
# 6
# 7
# 5A5
# 5A5
# 8
# 9
# 5A5
# 5A5
# 10
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/3A13.pdf
# 3A13
# Page 2 of 39
# Rev. 72
# Rev. 72
# Page 3 of 39
# 3A13
# 3A13
# Page 4 of 39
# Rev. 72
# Rev. 72
# Page 5 of 39
# 3A13
# 3A13
# Page 6 of 39
# Rev. 72
# Rev. 72
# Page 7 of 39
# 3A13
# 3A13
# Page 8 of 39
# Rev. 72
# Rev. 72
# Page 9 of 39
# 3A13
# 3A13
# Page 10 of 39
# Rev. 72
# Rev. 72
# Page 11 of 39
# 3A13
# 3A13
# Page 12 of 39
# Rev. 72
# Rev. 72
# Page 13 of 39
# 3A13
# 3A13
# Page 14 of 39
# Rev. 72
# Rev. 72
# Page 15 of 39
# 3A13
# 3A13
# Page 16 of 39
# Rev. 72
# Rev. 72
# Page 17 of 39
# 3A13
# 3A13
# Page 18 of 39
# Rev. 72
# Rev. 72
# Page 19 of 39
# 3A13
# 3A13
# Page 20 of 39
# Rev. 72
# Rev. 72
# Page 21 of 39
# 3A13
# 3A13
# Page 22 of 39
# Rev. 72
# Rev. 72
# Page 23 of 39
# 3A13
# 3A13
# Page 24 of 39
# Rev. 72
# Rev. 72
# Page 25 of 39
# 3A13
# 3A13
# Page 26 of 39
# Rev. 72
# Rev. 72
# Page 27 of 39
# 3A13
# 3A13
# Page 28 of 39
# Rev. 72
# Rev. 72
# Page 29 of 39
# 3A13
# 3A13
# Page 30 of 39
# Rev. 72
# Rev. 72
# Page 31 of 39
# Page 11 of 37
# A22CE
# A22CE
# Page 12 of 37
# Rev. 72
# Rev. 72
# Page 13 of 37
# A22CE
# A22CE
# Page 14 of 37
# Rev. 72
# Rev. 72
# Page 15 of 37
# A22CE
# A22CE
# Page 16 of 37
# Rev. 72
# Rev. 72
# Page 17 of 37
# A22CE
# A22CE
# Page 18 of 37
# Rev. 72
# Rev. 72
# Page 19 of 37
# A22CE
# A22CE
# Page 20 of 37
# Rev. 72
# Rev. 72
# Page 21 of 37
# A22CE
# A22CE
# Page 22 of 37
# Rev. 72
# Rev. 72
# Page 23 of 37
# A22CE
# A22CE
# Page 24 of 37
# Rev. 72
# Rev. 72
# Page 25 of 37
# A22CE
# A22CE
# Page 26 of 37
# Rev. 72
# Rev. 72
# Page 27 of 37
# A22CE
# A22CE
# Page 28 of 37
# Rev. 72
# Rev. 72
# Page 29 of 37
# A22CE
# A22CE
# Page 30 of 37
# Rev. 72
# Rev. 72
# Page 31 of 37
# A22CE
# A22CE
# Page 32 of 37
# Rev. 72
# Rev. 72
# Page 33 of 37
# A22CE
# A22CE
# Page 34 of 37
# Rev. 72
# Rev. 72
# Page 35 of 37
# A22CE
# A22CE
# Page 36 of 37
# Rev. 72
# Rev. 72
# Page 37 of 37
# A22CE
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/A11NM.pdf
# A11NM
# Page 2
# A11NM
# Page 3
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/A54NM.pdf
# A54NM
# Page 2 of 4
# Page 3 of 4
# A54NM
# A54NM
# Page 4 of 4
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/A-2-575.pdf
# Serial Nos. eligible
# All manufacturer's serial Nos. 55-1548 through 55-1630, 59-1631 through 59-1639, 59-
# 1906 through 59-1990, 65-1997 through 65-2032, 79-3983 through 79-4007. Harvard I
# 3
# A-2-575
# Items 1, 2, 101, 103, 104, 105, 109, 111, 201(a) or (b), 202(a) or (b), 203(a) or (b),
# 301(a), 405(a), (b) or (c), 406(a) or (b), 407, 602. Aluminum alloy outer wing panels
# (a) 12 volt - 68 amp. hr. (5 hr. rate) (Exide 6-TAS-17)
# 71 lbs. ( -1)
# 302. Generator
# 5
# A-2-575
# (i)
# For day operation, electrical protective devices in circuits to all equipment used in such operation should be
# accessible to the pilot in flight. The airplane should then be restricted to day operation.
# "Maintenance Interchangeability Cross Reference Charts" may be utilized as a guide.
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/7A2.pdf
# Airspeed limits (CAS)
# Vne (never exceed)
# 320 mph (278 knots or Mach.0.65
# whichever is the lesser)
# Page 3 of 4
# 7A2
# Standard mean
# 176.15 inches. The leading edge of the standard mean chord is at +550.62 inches.
# chord (S.M.C.)
# Certification basis
# CAR 10. Type Certificate No. 7A2, issued April 10, 1958. Date of Application
# for Type Certificate August 30, 1955.
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/R00024LA.pdf
# Page 2 of 5
# R00024LA
# Page 3 of 5
# R00024LA
# Page 4 of 5
# R00024LA
# Page 5 of 5
# R00024LA
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/A00059SE.pdf
# A00059SE
# 2
# A00059SE
# 3
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/4A23.pdf
# Leveling means
# Leveling lugs in tail cone area.
# Page 3 of 3
# 4A23
# NOTE 1.
# Current weight and balance report including list of equipment included in certificated empty weight, and
# loading instructions when necessary, must be in each aircraft at the time of original certification and at all
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/3
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/4A21.pdf
# 4A21
# 2
# 3
# 4A21
# 4A21
# 4
# 5
# 4A21
# 4A21
# 6
# 7
# 4A21
# 4A21
# 8
# 9
# 4A21
# 4A21
# 10
# 11
# 4A21
# 4A21
# 12
# 13
# 4A21
# 4A21
# 14
# 15
# 4A21
# 4A21
# 16
# 17
# 4A21
# 4A21
# 18
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/A2EU.pdf
# A2EU
# 2
# 3
# A2EU
# A2EU
# 4
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/A13NM.pdf
# A13NM
# Page 2 of 14
# Page 3 of 14
# A13NM
# A13NM
# Page 4 of 14
# Page 5 of 14
# A13NM
# A13NM
# Page 6 of 14
# Page 7 of 14
# A13NM
# A13NM
# Page 8 of 14
# Page 9 of 14
# A13NM
# A13NM
# Page 10 of 14
# Page 11 of 14
# A13NM
# A13NM
# Page 12 of 14
# Page 13 of 14
# A13NM
# A13NM
# Page 14 of 14
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/A56NM.pdf
# A56NM
# 2
# 3
# A56NM
# A56NM
# 4
# 5
# A56NM
# A56NM
# 6
# 7
# A56NM
# A56NM
# 8
# 9
# A56NM
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/A58CE.pdf
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/A2SO.pdf
# A2SO
# 2 of 9
# 3 of 9
# A2SO
# A2SO
# 4 of 9
# 5 of 9
# A2SO
# A2SO
# 6 of 9
# 7 of 9
# A2SO
# A2SO
# 8 of 9
# 9 of 9
# A2SO
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/A86EU.pdf
# Airspeed Limits
# VMO
# (maximum operating)
# KIAS
# KCAS
# Between 8,000 ft e 17,500 ft
# 350
# 353
# 3
# A86EU
# Engine oil Capacity
# Total 9.0 Lt. (2.39 U.S. Gal.)
# Usable 9.9 Lt. (0.5 U.S. Gal.)
# Refer to the applicable bilateral agreement to verify eligibility for import into the
# United States of both new and used aircraft based on the scope of the agreement,
# to identify any required statements by the exporting authority on the export
# certificate of airworthiness (or equivalent document), and for procedures for
# coordinating exceptions to conformity statements on these documents. Refer to
# Service Information
# Each of the documents listed below must state that it is approved by the European
# Aviation Safety Agency (EASA) or – for approvals made before September 28, 2003- by
# ENTE NAZIONALE per L’AVIAZONE CIVILE (ENAC). Any such documents are
# accepted by the FAA and are considered FAA approved.
# · Service bulletins
# · Structural Repair Manuals
# NOTE 4.
# As of January 1, 1997, AERMACCHI S.p.A. has acquired SIAI Marchetti S.r.L.
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/A2PC.pdf
# A2PC
# Page 2 of 23
# A2PC
# Page 3 of 23
# A2PC
# Page 4 of 23
# A2PC
# Page 5 of 23
# A2PC
# Page 6 of 23
# A2PC
# Page 7 of 23
# A2PC
# Page 8 of 23
# A2PC
# Page 9 of 23
# A2PC
# Page 10 of 23
# A2PC
# Page 11 of 23
# A2PC
# Page 12 of 23
# A2PC
# Page 13 of 23
# A2PC
# Page 14 of 23
# A2PC
# Page 15 of 23
# A2PC
# Page 16 of 23
# A2PC
# Page 17 of 23
# A2PC
# Page 18 of 23
# A2PC
# Page 19 of 23
# A2PC
# Page 20 of 23
# A2PC
# Page 21 of 23
# A2PC
# Page 22 of 23
# A2PC
# Page 23 of 23
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/A18EA.pdf
# A18EA
# A18EA
# A18EA
# A18EA
# A18EA
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/A-699.pdf
# A-699
# Page 2
# A-699
# Page 3
# A-699
# Page 4
# A-699
# Page 5
# A-699
# Page 6
# A-699
# Page 7
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/1
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/A26NM.pdf
# A26NM
# 2
# 3
# A26NM
# A26NM
# 4
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/7A9.pdf
# 7A9
# Page 2 of 4
# Page 3 of 4
# 7A9
# 7A9
# Page 4 of 4
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/A-684.pdf
# A-684
# 2
# Rev. 6
# Rev. 6
# 3
# A-684
# A-684
# 4
# Rev. 6
# Rev. 6
# 5
# A-684
# A-684
# 6
# Rev. 6
# Rev. 6
# 7
# A-684
# A-684
# 8
# Rev. 6
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/A73EU.pdf
# A73EU
# Page 2 of 8
# A73EU
# Page 3 of 8
# A73EU
# Page 4 of 8
# A73EU
# Page 5 of 8
# A73EU
# Page 6 of 8
# A73EU
# Page 7 of 8
# A73EU
# Page 8 of 8
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/A4SW.pdf
# A4SW
# 2
# A4SW
# 3
# A4SW
# 4
# A4SW
# 5
# A4SW
# 6
# A4SW
# 7
# A4SW
# 8
# A4SW
# 9
# A4SW
# 10
# A4SW
# 11
# A4SW
# 12
# A4SW
# 13
# A4SW
# 14
# A4SW
# 15
# A4SW
# 16
# A4SW
# 17
# A4SW
# 18
# A4SW
# 19
# A4SW
# 20
# A4SW
# 21
# A4SW
# 22
# A4SW
# 23
# A4SW
# 24
# A4SW
# 25
# A4SW
# 26
# A4SW
# 27
# A4SW
# 28
# A4SW
# 29
# A4SW
# 30
# A4SW
# 31
# A4SW
# 32
# A4SW
# 33
# A4SW
# 34
# A4SW
# 35
# A4SW
# 36
# A4SW
# 37
# A4SW
# 38
# A4SW
# 39
# A4SW
# 40
# A4SW
# 41
# A4SW
# 42
# A4SW
# 43
# A4SW
# 44
# A4SW
# 45
# A4SW
# 46
# A4SW
# 47
# A4SW
# 48
# A4SW
# 49
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/A36EU.pdf
# A36EU
# Page 2 of 6
# A36EU
# Page 3 of 6
# A36EU
# Page 4 of 6
# A36EU
# Page 5 of 6
# A36EU
# Page 6 of 6
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/A00053SE.pdf
# A00053SE
# Page 2 of 5
# Page 3 of 5
# A00053SE
# A00053SE
# Page 4 of 5
# Page 5 of 5
# A00053SE
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/H1CE.pdf
# HICE
# Page 2 of 41
# C.G. Limits
# Longitudinal (+92.0) to (+98.0)
# Page 3 of 41
# H1CE
# Rotor blade and
# control movements
# For rigging information, refer to Maintenance Manual.
# HICE
# Page 4 of 41
# IV - Model F-28C Helicopter, 3 PCLH (Normal Category), Approved December 8, 1975 (See NOTE 4)
# Engine
# Lycoming HIO-360-E1AD or HIO-360-E1BD with Rajay Model 301E10-2 or
# Page 5 of 41
# H1CE
# V - Model 280C Helicopter, 3 PCLH (Normal Category), Approved December 8, 1975 (See NOTE 4)
# Engine
# Lycoming HIO-360-E1AD or HIO-360-E1BD with Rajay Model 301E10-2 or
# HICE
# Page 6 of 41
# VI - Model 280C Helicopter, 3 PCLH (Normal Category), Modified per NOTE 5, Approved September 23, 1977
# (This version of the Model 280C differs from the basic Model 280C in that the installation of items listed on
# Enstrom Specification Drawing Number 28-100005 permits operation at a gross weight of 2350 lbs.)
# Page 7 of 41
# H1CE
# VII - Model F-28C Helicopter, 3 PCLH (Normal Category), Modified per NOTE 5, Approved April 21, 1978 (See
# NOTES 12 & 14)
# (This version of the Model F-28C differs from the basic Model F-28C in that installation of items listed on Enstrom
# HICE
# Page 8 of 41
# VIII - Model F-28C/280C Helicopter, 3 PCLH (Restricted Category), Modified per NOTE 6, Approved May 5,
# 1978, or NOTE 8, Approved July 28, 1982 (See NOTES 12 & 14)
# (This version is for agricultural operation or external load operation up to 2600 lbs. GW.)
# Page 9 of 41
# H1CE
# IX - Model F-28C/280C Helicopter, 3 PCLH (Normal Category), Modified per NOTE 7, Approved June 20, 1978
# (See NOTES 12 & 14)
# (This version is for operation with inflatable floats.)
# HICE
# Page 10 of 41
# X - Model F-28F/280F Helicopter, 3 PCLH (Normal Category), Approved December 31, 1980 (See NOTE 14, 35
# thru 38, 48, 59, 60, 64, 65, 71, and 72)
# (Models F-28F/280F are similar to F-28C/280C except for increased horsepower engine, improved turbocharger and
# Page 11 of 41
# H1CE
# Stabilizer Setting
# Fixed, 6 TE up relative to WL.
# Serial Nos. eligible
# F-28F Models: 506, 507, and 509 thru 743 (See NOTE 29 for ineligible serial
# HICE
# Page 12 of 41
# Control System Rigging
# Refer to Maintenance Manual.
# Stabilizer Setting
# Fixed, 6 TE up relative to WL.
# Page 13 of 41
# H1CE
# Stabilizer Setting
# F-28F: Fixed, 6 TE up relative to WL.
# 280F: Fixed, 6 TE up relative to WL, Trim tab per Dwg 28-17326.
# HICE
# Page 14 of 41
# Control System Rigging
# Refer to Maintenance Manual.
# Page 15 of 41
# H1CE
# Oil capacity
# 10 qts. (+96.0); See NOTE 1 for undrainable oil.
# (engine sump)
# HICE
# Page 16 of 41
# Fuel capacity
# 42 gal. (+96.7); See NOTE 1 for data on unusable fuel.
# Oil capacity
# 10 qts. (+96.0); See NOTE 1 for data on undrainable oil.
# Page 17 of 41
# H1CE
# Oil capacity
# 10 qts. (+96.0); See NOTE 1 for undrainable oil.
# (engine sump)
# HICE
# Page 18 of 41
# XVIII -Model 480 Helicopter, 5PLCH (Normal Category), Approved November 10, 1993 (See NOTES 19 thru 24,
# Page 19 of 41
# H1CE
# XIX - Model 480 Helicopter, 5PLCH (Normal Category), Originally Manufactured in Compliance with or Modified
# HICE
# Page 20 of 41
# XX - Model 480B Helicopter, 5PLCH (Normal Category), Approved February 8, 2001 (See NOTES 20 thru 24, 26,
# Page 21 of 41
# H1CE
# Data Pertinent to All Models
# HICE
# Page 22 of 41
# F-28A Models:
# Page 23 of 41
# H1CE
# HICE
# Page 24 of 41
# F-28F & 280F Models:
# Page 25 of 41
# H1CE
# HICE
# Page 26 of 41
# (k) FAA Approved Rotorcraft Flight Manual Supplement No. 28-AC-031 dated
# Page 27 of 41
# H1CE
# (f) FAA approved Rotorcraft Flight Manual Supplement No. 5 dated
# HICE
# Page 28 of 41
# Page 29 of 41
# H1CE
# (w) FAA approved Rotorcraft Flight Manual Supplement No. 28-AC-051 dated
# HICE
# Page 30 of 41
# (ak) FAA Approved Rotorcraft Flight Manual Supplement No. 28-AC-076 dated
# Page 31 of 41
# H1CE
# Normal
# Configured per NOTE 16
# HICE
# Page 32 of 41
# Page 33 of 41
# H1CE
# HICE
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/2H3.pdf
# 2H3
# 2 of 24
# 3 of 24
# 2H3
# 2H3
# 4 of 24
# 5 of 24
# 2H3
# 2H3
# 6 of 24
# 7 of 24
# 2H3
# 2H3
# 8 of 24
# 9 of 24
# 2H3
# 2H3
# 10 of 24
# 11 of 24
# 2H3
# 2H3
# 12 of 24
# 13 of 24
# 2H3
# 2H3
# 14 of 24
# 15 of 24
# 2H3
# 2H3
# 16 of 24
# 17 of 24
# 2H3
# 2H3
# 18 of 24
# 19 of 24
# 2H3
# 2H3
# 20 of 24
# 21 of 24
# 2H3
# 2H3
# 22 of 24
# 23 of 24
# 2H3
# 2H3
# 24 of 24
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/4A15.pdf
# Serial Numbers Eligible
# Consolidated Vultee Aircraft Corp. Serial numbering retained. All C.V.A.C. military
# models L-13 series aircraft when modified in accordance with Centaur Aircraft Company
# Page 3 of 6
# 4A15
# Production Basis
# None. Prior to original certification of aircraft converted in the United States, a FAA
# representative must perform a detailed inspection for workmanship, materials, and
# NOTE 1.
# Current weight and balance report including list of equipment included in certificated empty weight, and
# loading instructions when necessary, must be in each aircraft at the time or original certification and at all times
# thereafter (except in the case of air carrier operators having an approved weight control system).
# Page 5 of 6
# 4A15
# Fuel System
# Use 87 Octane minimum grade aviation fuel.
# Fuel system consists of 2 fuel tanks, one in each wing, with a capacity of 52.5 gallons each. One
# Engine and Propeller Limits:
# Engine
# Jacobs R755 A2
# Max. power, S.L. = 300 bhp at 2200 rpm, full throttle
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/H19NM.pdf
# H19NM
# 2 of 10
# 3 of 10
# H19NM
# H19NM
# 4 of 10
# 5 of 10
# H19NM
# H19NM
# 6 of 10
# 7 of 10
# H19NM
# H19NM
# 8 of 10
# 9 of 10
# H19NM
# H19NM
# 10 of 10
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/3A20.pdf
# 3A20
# 2
# Rev. 82
# 3A20
# 3
# Rev. 82
# 3A20
# 4
# Rev. 82
# 3A20
# 5
# Rev. 82
# 3A20
# 6
# Rev. 82
# 3A20
# 7
# Rev. 82
# 3A20
# 8
# Rev. 82
# 3A20
# 9
# Rev. 82
# 3A20
# 10
# Rev. 82
# 3A20
# 11
# Rev. 82
# 3A20
# 12
# Rev. 82
# 3A20
# 13
# Rev. 82
# 3A20
# 14
# Rev. 82
# 3A20
# 15
# Rev. 82
# 3A20
# 16
# Rev. 82
# 3A20
# 17
# Rev. 82
# 3A20
# 18
# Rev. 82
# 3A20
# 19
# Rev. 82
# 3A20
# 20
# Rev. 82
# 3A20
# 21
# Rev. 82
# 3A20
# 22
# Rev. 82
# 3A20
# 23
# Rev. 82
# 3A20
# 24
# Rev. 82
# 3A20
# 25
# Rev. 82
# 3A20
# 26
# Rev. 82
# 3A20
# 27
# Rev. 82
# 3A20
# 28
# Rev. 82
# 3A20
# 29
# Rev. 82
# 3A20
# 30
# Rev. 82
# 3A20
# 31
# Rev. 82
# 3A20
# 32
# Rev. 82
# 3A20
# 33
# Rev. 82
# 3A20
# 34
# Rev. 82
# 3A20
# 35
# Rev. 82
# 3A20
# 36
# Rev. 82
# 3A20
# 37
# Rev. 82
# 3A20
# 38
# Rev. 82
# 3A20
# 39
# Rev. 82
# /Users/bbteela/Desktop/Work/DAEN 690/Aviators/Data/dataset_tcds/4A29.pdf
# 4A29
# Page 2
# 4A29
# Page 3
