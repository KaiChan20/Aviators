# %%
import os 
import nltk

# get and set your working directory
os.getcwd()
os.chdir('/Users/sarojsiril/Desktop/DAEN 690/tcds/text/')
os.getcwd()

# open, read, and display the input file
textfile = open('A10CE_Rev_67.txt', mode='r')
allwords = textfile.read()
print(allwords)
# Out:
# DEPARTMENT OF TRANSPORTATION
# FEDERAL AVIATION ADMINISTRATION
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# A10CE
# Revision 67
# LEARJET
#
# 24
# 24A
# 24B
# 24B-A
# 24C
# 24D
# 24D-A
# 24E
# 24F
# 24F-A
# 25
# 25A
# 25B
# 25C
#
# 25D
# 25F
# 28
# 29
# 31
# 31A
# 35
# 36
# 35A (C-21A)
# 36A
# 55
# 55B
# 55C
# 60
#
#
#
# February 19, 2015
#
#
#     |
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     |
#
#
#
# TYPE CERTIFICATE DATA SHEET NO. A10CE
#
#
#
# Learjet Inc.
# One Learjet Way
# Wichita, Kansas  67209-2942
#
# This data sheet which is part of Type Certificate No. A10CE prescribes conditions and limitations under which the product for
# which the type certificate was issued meets the airworthiness requirements of the Federal Aviation Regulations.
#
# Type Certificate Holder
#
#
#
#
# I.  Model 24 (Transport Aircraft), Approved March 17, 1966
#   Model 24A (Transport Aircraft), Approved April 5, 1966
#
#   Engines
#
#
#
#   Fuel
#
#   Engine Limits
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...

# %%
from nltk.tokenize import RegexpTokenizer
tokenizer = RegexpTokenizer(r'\w+')
tokens = tokenizer.tokenize(allwords)
print(tokens)
# Out:
# ['DEPARTMENT', 'OF', 'TRANSPORTATION', 'FEDERAL', 'AVIATION', 'ADMINISTRATION', 'A10CE', 'Revision', '67', 'LEARJET', '24', '24A', '24B', '24B', 'A', '24C', '24D', '24D', 'A', '24E', '24F', '24F', 'A', '25', '25A', '25B', '25C', '25D', '25F', '28', '29', '31', '31A', '35', '36', '35A', 'C', '21A', '36A', '55', '55B', '55C', '60', 'February', '19', '2015', 'TYPE', 'CERTIFICATE', 'DATA', 'SHEET', 'NO', 'A10CE', 'Learjet', 'Inc', 'One', 'Learjet', 'Way', 'Wichita', 'Kansas', '67209', '2942', 'This', 'data', 'sheet', 'which', 'is', 'part', 'of', 'Type', 'Certificate', 'No', 'A10CE', 'prescribes', 'conditions', 'and', 'limitations', 'under', 'which', 'the', 'product', 'for', 'which', 'the', 'type', 'certificate', 'was', 'issued', 'meets', 'the', 'airworthiness', 'requirements', 'of', 'the', 'Federal', 'Aviation', 'Regulations', 'Type', 'Certificate', 'Holder', 'I', 'Model', '24', 'Transport', 'Aircraft', 'Approved', 'March', '17', '1966', 'Model', '24A', 'Transport', 'Aircraft', 'Approved
# ...

# %%
len(tokens)
# Out:
# 14754

# %%
for word in tokens:
    fdist[word.lower()]+=1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-b4e37a0020e9> in <module>
#       1 for word in tokens:
# ----> 2     fdist[word.lower()]+=1
#
# NameError: name 'fdist' is not defined

# %%
from nltk.tokenize import regexp_tokenize
regexp_tokenize(allwords,pattern='^A?\d{1,3}-?[CST]?')
# Out:
# ['A10C',
#  '24',
#  '24',
#  '24',
#  '24',
#  '24C',
#  '24',
#  '24',
#  '24',
#  '24',
#  '24',
#  '25',
#  '25',
#  '25',
#  '25C',
#  '25',
#  '25',
#  '28',
#  '29',
#  '31',
#  '31',
#  '35',
#  '36',
#  '35',
#  '36',
#  '55',
#  '55',
#  '55C',
#  '60',
#  '285',
#  '285',
#  '16',
#  '17',
#  '270',
#  '16',
#  '17',
#  '270',
#  '130',
#  '125',
#  '144',
#  '157',
#  '132',
#  '129',
#  '144',
#  '157',
#  '1',
#  '67',
#  '21',
#  '48',
#  '2',
#  '38',
#  '22',
#  '60',
#  '3',
#  '38',
#  '23',
#  '65',
#  '4',
#  '38',
#  '24',
#  '42',
#  '5',
#  '53',
#  '25',
#  '48',
#  '6',
#  '48',
#  '26',
#  '54',
#  '7',
#  '38',
#  '27',
#  '67',
#  '8',
#  '39',
#  '28',
#  '50',
#  '9',
#  '38',
#  '29',
#  '66',
#  '10',
#  '47',
#  '30',
#  '61',
#  '11',
#  '38',
#  '31',
#  '57',
#  '12',
#  '38',
#  '32',
#  '65',
#  '13',
#  '47',
#  '33',
#  '63',
#  '14',
#  '38',
#  '34',
#  '52',
#  '15',
#  '38',
#  '35',
#  '42',
#  '16',
#  '38',
#  '36',
#  '52',
#  '17',
# ...

# %%
sentences = nltk.sent_tokenize(allwords)
print(sentences)
# Out:
# ['DEPARTMENT OF TRANSPORTATION \nFEDERAL AVIATION ADMINISTRATION \n\n \n\n \n \n \n\n \n\n \n \n \n \n \n \n \n \n \n \n \n \n \n \n\n \n \n \n\nA10CE \nRevision 67 \nLEARJET \n\n24 \n24A \n24B \n24B-A \n24C \n24D \n24D-A \n24E \n24F \n24F-A \n25 \n25A \n25B \n25C \n\n25D \n25F \n28 \n29 \n31 \n31A \n35 \n36 \n35A (C-21A) \n36A \n55 \n55B \n55C \n60 \n\n \n\nFebruary 19, 2015 \n\n \n    | \n \n\n \n \n \n \n \n \n \n \n \n \n \n \n \n \n    | \n\n \n\nTYPE CERTIFICATE DATA SHEET NO.', 'A10CE \n\n \n\nLearjet Inc. \nOne Learjet Way \nWichita, Kansas  67209-2942 \n\nThis data sheet which is part of Type Certificate No.', 'A10CE prescribes conditions and limitations under which the product for \nwhich the type certificate was issued meets the airworthiness requirements of the Federal Aviation Regulations.', 'Type Certificate Holder \n \n \n \n \nI.', 'Model 24 (Transport Aircraft), Approved March 17, 1966 \n  Model 24A (Transport Aircraft), Approved April 5, 1966 \n \n  Engines \n \n \n
# ...
